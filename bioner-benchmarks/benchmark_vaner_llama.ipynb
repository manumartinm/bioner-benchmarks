# %%
# !pip install poetry
# %cd VANER
# !poetry lock --no-update
# !poetry install -q

# %%
# !poetry add huggingface_hub
# !poetry run huggingface-cli login

# %%
# !poetry add transformers[sentencepiece]

# %%
# !poetry run python ./vaner/mistral/unmistral_train_vaner.py ncbi 128 mt vaner 2
