# %% [markdown]
# ## Benchmarks VANER

# %% [markdown]
# ### Login en HuggingFace

# %%
# !poetry add huggingface_hub
# !poetry run huggingface-cli login

# %% [markdown]
# ### Llama

# %%
# !poetry run python ../VANER/vaner/mistral/unmistral_train_vaner.py ncbi 128 mt vaner 2
